# %% [markdown]
# <a href="https://colab.research.google.com/github/santiagoadiaz2108/CienciaDeDatos/blob/main/Pandas_Carolina_y_Santiago.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# 1. Crear un DataFrame con la base de datos completa de cancer
data = [
  {"ano": "2025","clasificacion_del_cancer": "Leucemia linfoide aguda","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2025","clasificacion_del_cancer": "Leucemia mileloide aguda","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2025","clasificacion_del_cancer": "Otras leucemias","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2025","clasificacion_del_cancer": "Tumores del sistema nervioso","_0_4_anos": "1","_5_9_anos": "3","_10_14_anos": "0","_15_19_anos": "0","total_general": "4","porcentaje_por_caso": "0.25"},
  {"ano": "2025","clasificacion_del_cancer": "Tumores hepáticos","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2025","clasificacion_del_cancer": "Otras neoplasias malignas","_0_4_anos": "1","_5_9_anos": "1","_10_14_anos": "0","_15_19_anos": "1","total_general": "3","porcentaje_por_caso": "0.19"},
  {"ano": "2025","clasificacion_del_cancer": "Sarcomas de tejidos blandos y extraóseos","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2025","clasificacion_del_cancer": "Tumores germinales trofoblásticos y otros gonadales","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2025","clasificacion_del_cancer": "Tumores oseos malignos","_0_4_anos": "1","_5_9_anos": "1","_10_14_anos": "1","_15_19_anos": "1","total_general": "4","porcentaje_por_caso": "0.25"},
  {"ano": "2025","clasificacion_del_cancer": "Tumores epiteliales malignos y melanoma","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2025","clasificacion_del_cancer": "Retinoblastoma","_0_4_anos": "0","_5_9_anos": "1","_10_14_anos": "0","_15_19_anos": "0","total_general": "1","porcentaje_por_caso": "0.06"},
  {"ano": "2025","clasificacion_del_cancer": "Tumores renales","_0_4_anos": "1","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "1","porcentaje_por_caso": "0.06"},
  {"ano": "2025","clasificacion_del_cancer": "Tumores epiteliales malignos y melanoma","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2025","clasificacion_del_cancer": "Linfomas y neoplasias reticuloendoteliales","_0_4_anos": "0","_5_9_anos": "1","_10_14_anos": "2","_15_19_anos": "0","total_general": "3","porcentaje_por_caso": "0.19"},
  {"ano": "2025","clasificacion_del_cancer": "Total","_0_4_anos": "4","_5_9_anos": "7","_10_14_anos": "3","_15_19_anos": "2","total_general": "16","porcentaje_por_caso": "1"},

  # Datos 2024
  {"ano": "2024","clasificacion_del_cancer": "Leucemia linfoide aguda","_0_4_anos": "1","_5_9_anos": "3","_10_14_anos": "0","_15_19_anos": "2","total_general": "6","porcentaje_por_caso": "0.24"},
  {"ano": "2024","clasificacion_del_cancer": "Leucemia mileloide aguda","_0_4_anos": "1","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "1","porcentaje_por_caso": "0.04"},
  {"ano": "2024","clasificacion_del_cancer": "Otras leucemias","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "1","_15_19_anos": "1","total_general": "2","porcentaje_por_caso": "0.08"},
  {"ano": "2024","clasificacion_del_cancer": "Tumores del sistema nervioso","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "3","_15_19_anos": "1","total_general": "4","porcentaje_por_caso": "0.16"},
  {"ano": "2024","clasificacion_del_cancer": "Tumores hepáticos","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2024","clasificacion_del_cancer": "Otras neoplasias malignas","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "3","_15_19_anos": "0","total_general": "3","porcentaje_por_caso": "0.12"},
  {"ano": "2024","clasificacion_del_cancer": "Sarcomas de tejidos blandos y extraóseos","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "1","total_general": "1","porcentaje_por_caso": "0.04"},
  {"ano": "2024","clasificacion_del_cancer": "Tumores germinales trofoblásticos y otros gonadales","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "1","_15_19_anos": "0","total_general": "1","porcentaje_por_caso": "0.04"},
  {"ano": "2024","clasificacion_del_cancer": "Tumores oseos malignos","_0_4_anos": "0","_5_9_anos": "1","_10_14_anos": "0","_15_19_anos": "2","total_general": "3","porcentaje_por_caso": "0.12"},
  {"ano": "2024","clasificacion_del_cancer": "Tumores epiteliales malignos y melanoma","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "1","_15_19_anos": "0","total_general": "1","porcentaje_por_caso": "0.04"},
  {"ano": "2024","clasificacion_del_cancer": "Retinoblastoma","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2024","clasificacion_del_cancer": "Tumores epiteliales malignos y melanoma","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2024","clasificacion_del_cancer": "Linfomas y neoplasias reticuloendoteliales","_0_4_anos": "0","_5_9_anos": "2","_10_14_anos": "1","_15_19_anos": "0","total_general": "3","porcentaje_por_caso": "0.12"},
  {"ano": "2024","clasificacion_del_cancer": "Total","_0_4_anos": "2","_5_9_anos": "6","_10_14_anos": "10","_15_19_anos": "7","total_general": "25","porcentaje_por_caso": "1"},

  # Datos 2023
  {"ano": "2023","clasificacion_del_cancer": "Leucemia linfoide aguda","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2023","clasificacion_del_cancer": "Leucemia mileloide aguda","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2023","clasificacion_del_cancer": "Otras leucemias","_0_4_anos": "1","_5_9_anos": "0","_10_14_anos": "1","_15_19_anos": "0","total_general": "2","porcentaje_por_caso": "0.22"},
  {"ano": "2023","clasificacion_del_cancer": "Tumores del sistema nervioso","_0_4_anos": "1","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "1","porcentaje_por_caso": "0.11"},
  {"ano": "2023","clasificacion_del_cancer": "Tumores hepáticos","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "1","total_general": "1","porcentaje_por_caso": "0.11"},
  {"ano": "2023","clasificacion_del_cancer": "Otras neoplasias malignas","_0_4_anos": "2","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "2","porcentaje_por_caso": "0.22"},
  {"ano": "2023","clasificacion_del_cancer": "Sarcomas de tejidos blandos y extraóseos","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2023","clasificacion_del_cancer": "Tumores germinales trofoblásticos y otros gonadales","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2023","clasificacion_del_cancer": "Tumores oseos malignos","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2023","clasificacion_del_cancer": "Tumores epiteliales malignos y melanoma","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2023","clasificacion_del_cancer": "Retinoblastoma","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2023","clasificacion_del_cancer": "Tumores epiteliales malignos y melanoma","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2023","clasificacion_del_cancer": "Linfomas y neoplasias reticuloendoteliales","_0_4_anos": "2","_5_9_anos": "1","_10_14_anos": "0","_15_19_anos": "0","total_general": "3","porcentaje_por_caso": "0.33"},
  {"ano": "2023","clasificacion_del_cancer": "Total","_0_4_anos": "6","_5_9_anos": "1","_10_14_anos": "1","_15_19_anos": "1","total_general": "9","porcentaje_por_caso": "1"},

  # Datos 2022
  {"ano": "2022","clasificacion_del_cancer": "Leucemia linfoide aguda","_0_4_anos": "3","_5_9_anos": "4","_10_14_anos": "2","_15_19_anos": "0","total_general": "9","porcentaje_por_caso": "0.29"},
  {"ano": "2022","clasificacion_del_cancer": "Leucemia mileloide aguda","_0_4_anos": "0","_5_9_anos": "1","_10_14_anos": "1","_15_19_anos": "1","total_general": "3","porcentaje_por_caso": "0.1"},
  {"ano": "2022","clasificacion_del_cancer": "Otras leucemias","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2022","clasificacion_del_cancer": "Tumores del sistema nervioso","_0_4_anos": "0","_5_9_anos": "1","_10_14_anos": "0","_15_19_anos": "1","total_general": "2","porcentaje_por_caso": "0.06"},
  {"ano": "2022","clasificacion_del_cancer": "Tumores hepáticos","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2022","clasificacion_del_cancer": "Otras neoplasias malignas","_0_4_anos": "1","_5_9_anos": "1","_10_14_anos": "3","_15_19_anos": "2","total_general": "7","porcentaje_por_caso": "0.22"},
  {"ano": "2022","clasificacion_del_cancer": "Sarcomas de tejidos blandos y extraóseos","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "1","total_general": "1","porcentaje_por_caso": "0.04"},
  {"ano": "2022","clasificacion_del_cancer": "Tumores germinales trofoblásticos y otros gonadales","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "1","_15_19_anos": "0","total_general": "1","porcentaje_por_caso": "0.04"},
  {"ano": "2022","clasificacion_del_cancer": "Tumores oseos malignos","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2022","clasificacion_del_cancer": "Tumores epiteliales malignos y melanoma","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2022","clasificacion_del_cancer": "Retinoblastoma","_0_4_anos": "1","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "1","porcentaje_por_caso": "0.04"},
  {"ano": "2022","clasificacion_del_cancer": "Tumores epiteliales malignos y melanoma","_0_4_anos": "0","_5_9_anos": "0","_10_14_anos": "0","_15_19_anos": "0","total_general": "0","porcentaje_por_caso": "0"},
  {"ano": "2022","clasificacion_del_cancer": "Linfomas y neoplasias reticuloendoteliales","_0_4_anos": "2","_5_9_anos": "2","_10_14_anos": "1","_15_19_anos": "2","total_general": "7","porcentaje_por_caso": "0.22"},
  {"ano": "2022","clasificacion_del_cancer": "Total","_0_4_anos": "7","_5_9_anos": "9","_10_14_anos": "8","_15_19_anos": "7","total_general": "31","porcentaje_por_caso": "100"}
]

df = pd.DataFrame(data)

print(df)
# Out:
#      ano                           clasificacion_del_cancer _0_4_anos  \
# 0   2025                            Leucemia linfoide aguda         0
# 1   2025                           Leucemia mileloide aguda         0
# 2   2025                                    Otras leucemias         0
# 3   2025                       Tumores del sistema nervioso         1
# 4   2025                                  Tumores hepáticos         0
# 5   2025                          Otras neoplasias malignas         1
# 6   2025           Sarcomas de tejidos blandos y extraóseos         0
# 7   2025  Tumores germinales trofoblásticos y otros gona...         0
# 8   2025                             Tumores oseos malignos         1
# 9   2025            Tumores epiteliales malignos y melanoma         0
# 10  2025                                     Retinoblastoma         0
# 11  2025                                    Tumores renales         1
# ...

# %%
#2. Seleccionar una columna del DataFrame para tener una vista rapida de datos especificos
print(df['ano'])
# Out:
# 0     2025
# 1     2025
# 2     2025
# 3     2025
# 4     2025
# 5     2025
# 6     2025
# 7     2025
# 8     2025
# 9     2025
# 10    2025
# 11    2025
# 12    2025
# 13    2025
# 14    2025
# 15    2024
# 16    2024
# 17    2024
# 18    2024
# 19    2024
# 20    2024
# 21    2024
# 22    2024
# 23    2024
# 24    2024
# 25    2024
# 26    2024
# 27    2024
# 28    2024
# 29    2023
# 30    2023
# 31    2023
# 32    2023
# 33    2023
# 34    2023
# 35    2023
# 36    2023
# 37    2023
# 38    2023
# 39    2023
# 40    2023
# 41    2023
# 42    2023
# 43    2022
# 44    2022
# 45    2022
# 46    2022
# 47    2022
# 48    2022
# 49    2022
# 50    2022
# 51    2022
# 52    2022
# 53    2022
# 54    2022
# 55    2022
# 56    2022
# Name: ano, dtype: object

# %%
#3. Crear una columna nueva según el total de casos

# Primero convertimos total_general a número
df['total_general'] = df['total_general'].astype(int)

# Creamos la nueva columna "tipo"
df['tipo'] = df['total_general'].apply(
    lambda x: 'Sin casos' if x == 0 else
              'Baja incidencia' if x <= 3 else
              'Alta incidencia'
)

# Mostrar solo las filas con alta incidencia
print(df.loc[df['tipo'] == 'Alta incidencia'])
# Out:
#      ano                    clasificacion_del_cancer _0_4_anos _5_9_anos  \
# 3   2025                Tumores del sistema nervioso         1         3
# 8   2025                      Tumores oseos malignos         1         1
# 14  2025                                       Total         4         7
# 15  2024                     Leucemia linfoide aguda         1         3
# 18  2024                Tumores del sistema nervioso         0         0
# 28  2024                                       Total         2         6
# 42  2023                                       Total         6         1
# 43  2022                     Leucemia linfoide aguda         3         4
# 48  2022                   Otras neoplasias malignas         1         1
# 55  2022  Linfomas y neoplasias reticuloendoteliales         2         2
# 56  2022                                       Total         7         9
#
#    _10_14_anos _15_19_anos  total_general porcentaje_por_caso             tipo
# ...

# %%
#4. Filtrar datos, para visualizar el subconjuto especifico de tipo de cancer
cancer= df[df['clasificacion_del_cancer']=='Leucemia linfoide aguda']
print(cancer)
# Out:
#      ano clasificacion_del_cancer _0_4_anos _5_9_anos _10_14_anos _15_19_anos  \
# 0   2025  Leucemia linfoide aguda         0         0           0           0
# 15  2024  Leucemia linfoide aguda         1         3           0           2
# 29  2023  Leucemia linfoide aguda         0         0           0           0
# 43  2022  Leucemia linfoide aguda         3         4           2           0
#
#     total_general porcentaje_por_caso             tipo
# 0               0                   0        Sin casos
# 15              6                0.24  Alta incidencia
# 29              0                   0        Sin casos
# 43              9                0.29  Alta incidencia

# %%
#5. Estadistica descriptiva
print(df.describe())
# Out:
#        total_general
# count      57.000000
# mean        2.842105
# std         5.693949
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         3.000000
# max        31.000000

# %%
#6. Eliminar columnas
df = df.drop('porcentaje_por_caso', axis=1)
print(df)
# Out:
#      ano                           clasificacion_del_cancer _0_4_anos  \
# 0   2025                            Leucemia linfoide aguda         0
# 1   2025                           Leucemia mileloide aguda         0
# 2   2025                                    Otras leucemias         0
# 3   2025                       Tumores del sistema nervioso         1
# 4   2025                                  Tumores hepáticos         0
# 5   2025                          Otras neoplasias malignas         1
# 6   2025           Sarcomas de tejidos blandos y extraóseos         0
# 7   2025  Tumores germinales trofoblásticos y otros gona...         0
# 8   2025                             Tumores oseos malignos         1
# 9   2025            Tumores epiteliales malignos y melanoma         0
# 10  2025                                     Retinoblastoma         0
# 11  2025                                    Tumores renales         1
# ...

# %%
# 7. Agregar nuevas columnas
df['Promedio_edades'] = (
    df['_0_4_anos'].astype(int) +
    df['_5_9_anos'].astype(int) +
    df['_10_14_anos'].astype(int) +
    df['_15_19_anos'].astype(int)
) / 4

print(df)
# Out:
#      ano                           clasificacion_del_cancer _0_4_anos  \
# 0   2025                            Leucemia linfoide aguda         0
# 1   2025                           Leucemia mileloide aguda         0
# 2   2025                                    Otras leucemias         0
# 3   2025                       Tumores del sistema nervioso         1
# 4   2025                                  Tumores hepáticos         0
# 5   2025                          Otras neoplasias malignas         1
# 6   2025           Sarcomas de tejidos blandos y extraóseos         0
# 7   2025  Tumores germinales trofoblásticos y otros gona...         0
# 8   2025                             Tumores oseos malignos         1
# 9   2025            Tumores epiteliales malignos y melanoma         0
# 10  2025                                     Retinoblastoma         0
# 11  2025                                    Tumores renales         1
# ...

# %%
#8 operaciones con columnas
df['menores_10'] = df['_0_4_anos'].astype(int) + df['_5_9_anos'].astype(int)
print(df)
# Out:
#      ano                           clasificacion_del_cancer _0_4_anos  \
# 0   2025                            Leucemia linfoide aguda         0
# 1   2025                           Leucemia mileloide aguda         0
# 2   2025                                    Otras leucemias         0
# 3   2025                       Tumores del sistema nervioso         1
# 4   2025                                  Tumores hepáticos         0
# 5   2025                          Otras neoplasias malignas         1
# 6   2025           Sarcomas de tejidos blandos y extraóseos         0
# 7   2025  Tumores germinales trofoblásticos y otros gona...         0
# 8   2025                             Tumores oseos malignos         1
# 9   2025            Tumores epiteliales malignos y melanoma         0
# 10  2025                                     Retinoblastoma         0
# 11  2025                                    Tumores renales         1
# ...
